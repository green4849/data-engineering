# %% [markdown]
# ## <strong>9. RESTful API를 이용한 데이터 취득</strong>

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in C:\Users\kong0\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\kong0\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\kong0\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\kong0\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.3 MB 10.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.3 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.3 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 11.8 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 13.1 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.9/7.2 MB 14.2 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.2 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 13.0 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.2.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\kong0\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import requests  # HTTP 통신 라이브러리
import matplotlib.pyplot as plt #a 데이터 시각화
import time # API 요청 제한(Rate Limit) 우회를 위한 시간 제어

# %%
# 1. 상위 100개 코인 정보 가져오기 (Data Acquisition 단계)
def get_top_100_coins():
    """
    CoinGecko API를 통해 시장의 원천 데이터(Raw Data)를 취득
    """
    url = "https://api.coingecko.com/api/v3/coins/markets"
    
    # API 요청 파라미터 설정
    params = {
        "vs_currency": "usd",        # 통화 단위: USD
        "order": "market_cap_desc",  # 정렬 기준: 시가총액 내림차순
        "per_page": 100,             # 취득할 데이터 양: 100개
        "page": 1,                   # 페이지 번호
        "sparkline": False           # 데이터 부하를 줄이기 위해 그래프 데이터 제외
    }
    
    # RESTful API 호출 (HTTP GET 방식)
    response = requests.get(url, params=params)
    
    # 응답받은 JSON 데이터를 파이썬 객체로 변환
    return response.json()

# %%
# 2. 특정 코인의 시가총액 추이 가져오기
def get_market_chart(coin_id):
    """
    특정 코인의 ID를 사용하여 시계열 데이터를 요청
    """
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart"
    params = {
        "vs_currency": "usd",
        "days": 365,          # 데이터 범위: 최근 365일
        "interval": "daily"   # 데이터 간격: 일 단위 (데이터 정제 과정)
    }
    
    response = requests.get(url, params=params)
    
    # HTTP 상태 코드가 200(성공)일 경우에만 데이터 반환 (예외 처리)
    if response.status_code == 200:
        return response.json()["market_caps"]
    else:
        # 데이터 취득 실패 시 빈 리스트 반환
        return []

# %%
# 3. 시각화 함수 
def plot_market_caps(coin_data):
    """
    가공된 데이터를 바탕으로 분석용 차트를 생성
    """
    plt.figure(figsize=(16, 10))

    for coin_name, market_caps in coin_data.items():
        if not market_caps:
            continue
            
        timestamps = [cap[0] for cap in market_caps] # x축: 타임스탬프
        
        # 데이터 스케일링: 가독성을 위해 달러 단위를 10억(Billion) 단위로 변환
        values = [cap[1] / 1e9 for cap in market_caps] 
        
        plt.plot(timestamps, values, label=coin_name)

    # 시각화
    plt.title("Top 100 Alt Coins - Market Cap Trend (Last 365 Days)")
    plt.xlabel("Timestamp")
    plt.ylabel("Market Cap (Billion USD)")
    plt.xticks(rotation=45)
    plt.legend(fontsize="small", loc="upper left", ncol=2)
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %%
# --- 메인 실행 흐름 ---

print("🚀 상위 100개 코인 정보를 불러오는 중...")
all_coins = get_top_100_coins()

# 데이터 필터링: 시장 지배력이 너무 큰 BTC, ETH를 제외하여 주요 알트코인들의 추이를 비교
coins = all_coins[2:] 

coin_market_data = {}

# 반복문을 통한 대량 데이터 취득
for i, coin in enumerate(coins):
    coin_id = coin["id"]
    coin_name = coin["name"]
    
    print(f"📈 데이터 수집 중: {coin_name} ({i+1}/100)")
    market_caps = get_market_chart(coin_id)
    
    # 딕셔너리에 데이터 적재
    coin_market_data[coin_name] = market_caps
    
    # API 요청 제한 우회
    time.sleep(1.2) 

    # 실습 효율을 위해 상위 4개 알트코인만 수집 후 중단
    if i >= 3: 
        break
# Out:
# 🚀 상위 100개 코인 정보를 불러오는 중...
# 📈 데이터 수집 중: Tether (1/100)
# 📈 데이터 수집 중: XRP (2/100)
# 📈 데이터 수집 중: BNB (3/100)
# 📈 데이터 수집 중: USDC (4/100)

# %%
# 최종 가공된 데이터를 시각화
plot_market_caps(coin_market_data)

# %%
# get_top_100_coins() 응답 내용(JSON) 확인
coins
# Out:
# [{'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 184735273804,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 190204014828,
#   'total_volume': 97147043284,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.00020735,
#   'price_change_percentage_24h': 0.02073,
#   'market_cap_change_24h': 275111896,
#   'market_cap_change_percentage_24h': 0.14914,
#   'circulating_supply': 184674430497.4122,
#   'total_supply': 190141370368.7762,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.39645,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.7197,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:53.917Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 1.39,
#   'market_cap': 85547660872,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 139295947103,
#   'total_volume': 3058360536,
#   'high_24h': 1.39,
#   'low_24h': 1.33,
#   'price_change_24h': 0.054331,
#   'price_change_percentage_24h': 4.06264,
#   'market_cap_change_24h': 3323924004,
#   'market_cap_change_percentage_24h': 4.04254,
#   'circulating_supply': 61405531717.0,
#   'total_supply': 99985687636.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.65,
#   'ath_change_percentage': -61.83401,
#   'ath_date': '2025-07-18T03:40:53.808Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 51708.2352,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:56.759Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 621.66,
#   'market_cap': 84825273647,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 84825273647,
#   'total_volume': 1510854583,
#   'high_24h': 622.53,
#   'low_24h': 598.76,
#   'price_change_24h': 21.76,
#   'price_change_percentage_24h': 3.62814,
#   'market_cap_change_24h': 2952874405,
#   'market_cap_change_percentage_24h': 3.60668,
#   'circulating_supply': 136356333.56,
#   'total_supply': 136356333.56,
#   'max_supply': 200000000.0,
#   'ath': 1369.99,
#   'ath_change_percentage': -54.62332,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1561157.25627,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:53.769Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 0.999711,
#   'market_cap': 78643623276,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 78683873442,
#   'total_volume': 20759056120,
#   'high_24h': 1.0,
#   'low_24h': 0.99801,
#   'price_change_24h': -0.000126720415667747,
#   'price_change_percentage_24h': -0.01267,
#   'market_cap_change_24h': 54730343,
#   'market_cap_change_percentage_24h': 0.06964,
#   'circulating_supply': 78662903373.9202,
#   'total_supply': 78703163407.91751,
#   'max_supply': None,
#   'ath': 1.043,
#   'ath_change_percentage': -4.18926,
#   'ath_date': '2018-11-15T00:00:00.000Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.91272,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:53.645Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 87.16,
#   'market_cap': 50209790440,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 54508943242,
#   'total_volume': 4989851302,
#   'high_24h': 87.34,
#   'low_24h': 82.44,
#   'price_change_24h': 3.72,
#   'price_change_percentage_24h': 4.46221,
#   'market_cap_change_24h': 2231786559,
#   'market_cap_change_percentage_24h': 4.65169,
#   'circulating_supply': 575141408.8610724,
#   'total_supply': 624387198.9197268,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -70.28547,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 17303.36521,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:04.250Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/photo_2026-04-13_09-59-16.png?1776048311',
#   'current_price': 0.320859,
#   'market_cap': 30417655883,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 30417664710,
#   'total_volume': 506211450,
#   'high_24h': 0.32168,
#   'low_24h': 0.319321,
#   'price_change_24h': 0.0002198,
#   'price_change_percentage_24h': 0.06855,
#   'market_cap_change_24h': 32490867,
#   'market_cap_change_percentage_24h': 0.10693,
#   'circulating_supply': 94774374010.08409,
#   'total_supply': 94774401514.6126,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -25.60454,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 17682.60612,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 167.87313994297517,
#    'currency': 'usd',
#    'percentage': 16787.313994297514},
#   'last_updated': '2026-04-14T14:03:47.080Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 1.027,
#   'market_cap': 17178999110,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 17178999110,
#   'total_volume': 14802046,
#   'high_24h': 1.03,
#   'low_24h': 1.017,
#   'price_change_24h': 0.007334,
#   'price_change_percentage_24h': 0.71934,
#   'market_cap_change_24h': 209453751,
#   'market_cap_change_percentage_24h': 1.23429,
#   'circulating_supply': 16729421014.127,
#   'total_supply': 16729421014.127,
#   'max_supply': None,
#   'ath': 1.049,
#   'ath_change_percentage': -2.12036,
#   'ath_date': '2026-03-09T17:00:25.937Z',
#   'atl': 0.155357,
#   'atl_change_percentage': 560.97836,
#   'atl_date': '2025-10-31T14:27:24.456Z',
#   'roi': None,
#   'last_updated': '2026-04-14T05:18:27.512Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.097399,
#   'market_cap': 14961839720,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 16490022275,
#   'total_volume': 2172302139,
#   'high_24h': 0.097011,
#   'low_24h': 0.091507,
#   'price_change_24h': 0.00555388,
#   'price_change_percentage_24h': 6.04698,
#   'market_cap_change_24h': 835843920,
#   'market_cap_change_percentage_24h': 5.91706,
#   'circulating_supply': 153827196383.7052,
#   'total_supply': 169538903126.5791,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -86.6864,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 111977.27498,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:59.350Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 55.38,
#   'market_cap': 11820607153,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 17702074518,
#   'total_volume': 85876945,
#   'high_24h': 55.39,
#   'low_24h': 52.45,
#   'price_change_24h': 2.88,
#   'price_change_percentage_24h': 5.47958,
#   'market_cap_change_24h': 616054914,
#   'market_cap_change_percentage_24h': 5.49826,
#   'circulating_supply': 213418274.0,
#   'total_supply': 319606780.0,
#   'max_supply': 400000000.0,
#   'ath': 64.11,
#   'ath_change_percentage': -13.55965,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 3.06,
#   'atl_change_percentage': 1709.88791,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:03.485Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999755,
#   'market_cap': 11323711516,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 11323711516,
#   'total_volume': 78590881,
#   'high_24h': 1.0,
#   'low_24h': 0.999459,
#   'price_change_24h': -9.287681369097e-06,
#   'price_change_percentage_24h': -0.00093,
#   'market_cap_change_24h': -73873636.43657494,
#   'market_cap_change_percentage_24h': -0.64815,
#   'circulating_supply': 11326021894.97287,
#   'total_supply': 11326021894.97287,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.22279,
#   'ath_date': '2026-04-02T07:21:14.655Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.42941,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:57.932Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 44.35,
#   'market_cap': 10639339809,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 42947109988,
#   'total_volume': 457695447,
#   'high_24h': 45.12,
#   'low_24h': 42.08,
#   'price_change_24h': 1.88,
#   'price_change_percentage_24h': 4.4224,
#   'market_cap_change_24h': 472190425,
#   'market_cap_change_percentage_24h': 4.64428,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 59.3,
#   'ath_change_percentage': -25.20769,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 3.81,
#   'atl_change_percentage': 1064.54709,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.658Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 10.14,
#   'market_cap': 9305858432,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 9956611495,
#   'total_volume': 576597,
#   'high_24h': 10.16,
#   'low_24h': 10.08,
#   'price_change_24h': 0.01645834,
#   'price_change_percentage_24h': 0.16256,
#   'market_cap_change_24h': -17135818.750429153,
#   'market_cap_change_percentage_24h': -0.1838,
#   'circulating_supply': 920845344.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.2,
#   'ath_change_percentage': -0.88601,
#   'ath_date': '2026-04-08T16:00:43.393Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1163.44456,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.755Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.248598,
#   'market_cap': 9177492861,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 11179834864,
#   'total_volume': 525805802,
#   'high_24h': 0.248701,
#   'low_24h': 0.237976,
#   'price_change_24h': 0.00609958,
#   'price_change_percentage_24h': 2.51531,
#   'market_cap_change_24h': 221085803,
#   'market_cap_change_percentage_24h': 2.46847,
#   'circulating_supply': 36940364839.85039,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -91.94671,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 1191.23346,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:52.203Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 442.95,
#   'market_cap': 8853832324,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 8853955318,
#   'total_volume': 232212526,
#   'high_24h': 442.62,
#   'low_24h': 425.58,
#   'price_change_24h': 15.46,
#   'price_change_percentage_24h': 3.6172,
#   'market_cap_change_24h': 304185201,
#   'market_cap_change_percentage_24h': 3.55787,
#   'circulating_supply': 20021034.27165078,
#   'total_supply': 20021312.39665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -88.29975,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 475.74767,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:54.476Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 9.23,
#   'market_cap': 6717279030,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 9238453174,
#   'total_volume': 473398665,
#   'high_24h': 9.4,
#   'low_24h': 8.79,
#   'price_change_24h': 0.410533,
#   'price_change_percentage_24h': 4.65567,
#   'market_cap_change_24h': 292789328,
#   'market_cap_change_percentage_24h': 4.55739,
#   'circulating_supply': 727099970.4523476,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -82.4875,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 6127.75946,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:03.318Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 353.44,
#   'market_cap': 6516780166,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 6516780166,
#   'total_volume': 108531491,
#   'high_24h': 353.18,
#   'low_24h': 343.29,
#   'price_change_24h': 7.92,
#   'price_change_percentage_24h': 2.29368,
#   'market_cap_change_24h': 139142740,
#   'market_cap_change_percentage_24h': 2.18173,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 797.73,
#   'ath_change_percentage': -55.69507,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 163393.98768,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.176Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 367.9,
#   'market_cap': 6140366996,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 6140813396,
#   'total_volume': 639078126,
#   'high_24h': 381.27,
#   'low_24h': 345.51,
#   'price_change_24h': 3.83,
#   'price_change_percentage_24h': 1.0526,
#   'market_cap_change_24h': 70089615,
#   'market_cap_change_percentage_24h': 1.15464,
#   'circulating_supply': 16656784.5405448,
#   'total_supply': 16657995.4780448,
#   'max_supply': 21000000.0,
#   'ath': 3191.93,
#   'ath_change_percentage': -88.47402,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 16.08,
#   'atl_change_percentage': 2187.92423,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.846Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 0.156027,
#   'market_cap': 5976167739,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 5976167739,
#   'total_volume': 30317076,
#   'high_24h': 0.160445,
#   'low_24h': 0.148629,
#   'price_change_24h': 0.00718268,
#   'price_change_percentage_24h': 4.82564,
#   'market_cap_change_24h': 274851444,
#   'market_cap_change_percentage_24h': 4.82084,
#   'circulating_supply': 38309740365.3041,
#   'total_supply': 38309740365.3041,
#   'max_supply': None,
#   'ath': 0.194152,
#   'ath_change_percentage': -19.71927,
#   'ath_date': '2026-02-03T08:02:08.411Z',
#   'atl': 0.059024,
#   'atl_change_percentage': 164.07264,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.508Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 1.0,
#   'market_cap': 5829287049,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 5829287049,
#   'total_volume': 122982147,
#   'high_24h': 1.001,
#   'low_24h': 0.998774,
#   'price_change_24h': 0.00020288,
#   'price_change_percentage_24h': 0.02029,
#   'market_cap_change_24h': 373646,
#   'market_cap_change_percentage_24h': 0.00641,
#   'circulating_supply': 5828297803.804168,
#   'total_supply': 5828297803.804168,
#   'max_supply': None,
#   'ath': 1.034,
#   'ath_change_percentage': -3.27094,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.60803,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.907Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.158271,
#   'market_cap': 5234387351,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 7906800987,
#   'total_volume': 90683009,
#   'high_24h': 0.15804,
#   'low_24h': 0.151488,
#   'price_change_24h': 0.00519374,
#   'price_change_percentage_24h': 3.3929,
#   'market_cap_change_24h': 163863762,
#   'market_cap_change_percentage_24h': 3.23169,
#   'circulating_supply': 33101721068.938,
#   'total_supply': 50001786883.65895,
#   'max_supply': None,
#   'ath': 0.875563,
#   'ath_change_percentage': -81.96563,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 33064.15115,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:02.532Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 2.86,
#   'market_cap': 5015376862,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 15289019320,
#   'total_volume': 18853645,
#   'high_24h': 2.99,
#   'low_24h': 2.7,
#   'price_change_24h': 0.00208445,
#   'price_change_percentage_24h': 0.07306,
#   'market_cap_change_24h': 2016540,
#   'market_cap_change_percentage_24h': 0.04022,
#   'circulating_supply': 1757444526.110493,
#   'total_supply': 5357444525.669769,
#   'max_supply': 10000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -4.55748,
#   'ath_date': '2026-04-13T15:05:06.618Z',
#   'atl': 0.04746135,
#   'atl_change_percentage': 5909.78993,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.923Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999272,
#   'market_cap': 4369533909,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 4369533909,
#   'total_volume': 73535557,
#   'high_24h': 1.002,
#   'low_24h': 0.994766,
#   'price_change_24h': 0.00111755,
#   'price_change_percentage_24h': 0.11196,
#   'market_cap_change_24h': -31692349.04611492,
#   'market_cap_change_percentage_24h': -0.72008,
#   'circulating_supply': 4372315348.239364,
#   'total_supply': 4372315348.239364,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -18.01609,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.30753,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.990Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 55.2,
#   'market_cap': 4251499236,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 4251673378,
#   'total_volume': 422737444,
#   'high_24h': 55.15,
#   'low_24h': 52.87,
#   'price_change_24h': 2.14,
#   'price_change_percentage_24h': 4.02912,
#   'market_cap_change_24h': 156831337,
#   'market_cap_change_percentage_24h': 3.83014,
#   'circulating_supply': 77056614.48347135,
#   'total_supply': 77059770.73347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -86.55948,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 4699.70578,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:47.875Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 9.5,
#   'market_cap': 4101345126,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 4402165746,
#   'total_volume': 366949708,
#   'high_24h': 9.68,
#   'low_24h': 9.17,
#   'price_change_24h': 0.266367,
#   'price_change_percentage_24h': 2.88543,
#   'market_cap_change_24h': 110270737,
#   'market_cap_change_percentage_24h': 2.76293,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -93.45026,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 238.96366,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:46.927Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 0.999526,
#   'market_cap': 4088516654,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 4088516654,
#   'total_volume': 1608321744,
#   'high_24h': 0.999955,
#   'low_24h': 0.998624,
#   'price_change_24h': 0.00068708,
#   'price_change_percentage_24h': 0.06879,
#   'market_cap_change_24h': -39884558.92117596,
#   'market_cap_change_percentage_24h': -0.9661,
#   'circulating_supply': 4090850722.162925,
#   'total_supply': 4090850722.162925,
#   'max_supply': None,
#   'ath': 1.025,
#   'ath_change_percentage': -2.47857,
#   'ath_date': '2025-05-12T12:36:39.412Z',
#   'atl': 0.989633,
#   'atl_change_percentage': 0.98949,
#   'atl_date': '2025-10-01T08:51:32.103Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:50.625Z'},
#  {'id': 'ravedao',
#   'symbol': 'rave',
#   'name': 'RaveDAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/70544/large/coin.jpeg?1762452940',
#   'current_price': 16.44,
#   'market_cap': 4083786318,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 16463929819,
#   'total_volume': 726149201,
#   'high_24h': 16.78,
#   'low_24h': 7.49,
#   'price_change_24h': 6.58,
#   'price_change_percentage_24h': 66.70096,
#   'market_cap_change_24h': 1635674787,
#   'market_cap_change_percentage_24h': 66.81374,
#   'circulating_supply': 248044444.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 16.78,
#   'ath_change_percentage': -1.96425,
#   'ath_date': '2026-04-14T12:10:18.905Z',
#   'atl': 0.206266,
#   'atl_change_percentage': 7877.42125,
#   'atl_date': '2026-03-12T02:10:18.440Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.607Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 1.0,
#   'market_cap': 4047065156,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 4047065156,
#   'total_volume': 117982112,
#   'high_24h': 1.0,
#   'low_24h': 0.999454,
#   'price_change_24h': 0.00021566,
#   'price_change_percentage_24h': 0.02157,
#   'market_cap_change_24h': 31507623,
#   'market_cap_change_percentage_24h': 0.78464,
#   'circulating_supply': 4047308801.391996,
#   'total_supply': 4047308801.391996,
#   'max_supply': None,
#   'ath': 1.081,
#   'ath_change_percentage': -7.47154,
#   'ath_date': '2026-04-02T07:35:31.426Z',
#   'atl': 0.959426,
#   'atl_change_percentage': 4.23841,
#   'atl_date': '2024-12-05T22:31:13.430Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.439Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.00803898,
#   'market_cap': 3846513470,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 9246477961,
#   'total_volume': 17120069,
#   'high_24h': 0.00819491,
#   'low_24h': 0.00782168,
#   'price_change_24h': 6.822e-05,
#   'price_change_percentage_24h': 0.85592,
#   'market_cap_change_24h': 33624580,
#   'market_cap_change_percentage_24h': 0.88187,
#   'circulating_supply': 478357735700.3372,
#   'total_supply': 1149904789136.956,
#   'max_supply': 1150000000000.0,
#   'ath': 0.01090099,
#   'ath_change_percentage': -26.25254,
#   'ath_date': '2026-02-09T16:50:09.904Z',
#   'atl': 0.00222126,
#   'atl_change_percentage': 261.9209,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.163Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 0.959257,
#   'market_cap': 3793887803,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 9596545820,
#   'total_volume': 377152962,
#   'high_24h': 0.96054,
#   'low_24h': 0.911578,
#   'price_change_24h': 0.04284176,
#   'price_change_percentage_24h': 4.67493,
#   'market_cap_change_24h': 170711172,
#   'market_cap_change_percentage_24h': 4.71164,
#   'circulating_supply': 3953388932.071221,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -82.05845,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 162.9209,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.222Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.087534,
#   'market_cap': 3792625434,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 4377375746,
#   'total_volume': 86301180,
#   'high_24h': 0.087943,
#   'low_24h': 0.084704,
#   'price_change_24h': 0.00148821,
#   'price_change_percentage_24h': 1.72955,
#   'market_cap_change_24h': 61324803,
#   'market_cap_change_percentage_24h': 1.64352,
#   'circulating_supply': 43320766299.19269,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -84.62637,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 787.43689,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.031Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 1.43,
#   'market_cap': 3555779782,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 7395314606,
#   'total_volume': 108761914,
#   'high_24h': 1.45,
#   'low_24h': 1.42,
#   'price_change_24h': 0.00569264,
#   'price_change_percentage_24h': 0.39907,
#   'market_cap_change_24h': 15409061,
#   'market_cap_change_percentage_24h': 0.43524,
#   'circulating_supply': 2482229599.350126,
#   'total_supply': 5162543783.976174,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -82.65178,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 175.6938,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:03.592Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 6e-06,
#   'market_cap': 3537301088,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 3538841282,
#   'total_volume': 136671236,
#   'high_24h': 6e-06,
#   'low_24h': 5.76e-06,
#   'price_change_24h': 1.96798e-07,
#   'price_change_percentage_24h': 3.39,
#   'market_cap_change_24h': 114319352,
#   'market_cap_change_percentage_24h': 3.33976,
#   'circulating_supply': 589243521383479.8,
#   'total_supply': 589500086857209.4,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -93.03374,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 10648168.60716,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.247Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.070613,
#   'market_cap': 2991357836,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 6960851859,
#   'total_volume': 13323418,
#   'high_24h': 0.070834,
#   'low_24h': 0.068181,
#   'price_change_24h': 0.00216086,
#   'price_change_percentage_24h': 3.15673,
#   'market_cap_change_24h': 91108184,
#   'market_cap_change_percentage_24h': 3.14139,
#   'circulating_supply': 42351557608.66594,
#   'total_supply': 98551539023.36035,
#   'max_supply': 100000000000.0,
#   'ath': 0.891544,
#   'ath_change_percentage': -92.07759,
#   'ath_date': '2021-11-24T00:00:00.000Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 482.7898,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.754Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 1.12,
#   'market_cap': 2682570081,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 2682570081,
#   'total_volume': 112099,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 2393041089.101221,
#   'total_supply': 2393041089.101221,
#   'max_supply': None,
#   'ath': 1.12,
#   'ath_change_percentage': -0.09236,
#   'ath_date': '2026-04-08T14:31:05.529Z',
#   'atl': 1.026,
#   'atl_change_percentage': 9.24713,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-04-09T23:06:04.591Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/logo.png?1774627372',
#   'current_price': 4776.27,
#   'market_cap': 2672593671,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 3378929366,
#   'total_volume': 373061704,
#   'high_24h': 4773.24,
#   'low_24h': 4677.98,
#   'price_change_24h': 74.99,
#   'price_change_percentage_24h': 1.59516,
#   'market_cap_change_24h': 41888622,
#   'market_cap_change_percentage_24h': 1.5923,
#   'circulating_supply': 559798.736688,
#   'total_supply': 707747.089,
#   'max_supply': None,
#   'ath': 5504.62,
#   'ath_change_percentage': -13.32323,
#   'ath_date': '2026-01-29T00:00:00.000Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 229.54048,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:46.803Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 0.083073,
#   'market_cap': 2642987633,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 8321015411,
#   'total_volume': 78577778,
#   'high_24h': 0.083175,
#   'low_24h': 0.078985,
#   'price_change_24h': 0.0038463,
#   'price_change_percentage_24h': 4.85482,
#   'market_cap_change_24h': 125592942,
#   'market_cap_change_percentage_24h': 4.989,
#   'circulating_supply': 31762801799.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.331336,
#   'ath_change_percentage': -74.92797,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 0.07726,
#   'atl_change_percentage': 7.5233,
#   'atl_date': '2026-04-11T07:56:04.528Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.681Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 1.0,
#   'market_cap': 2494070875,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 2494070875,
#   'total_volume': 0.0,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 50691379,
#   'market_cap_change_percentage_24h': 2.07464,
#   'circulating_supply': 2494070874.510449,
#   'total_supply': 2494070874.510449,
#   'max_supply': None,
#   'ath': 1.0,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2025-02-12T05:00:10.912Z',
#   'atl': 1.0,
#   'atl_change_percentage': 0.0,
#   'atl_date': '2025-02-12T05:45:10.196Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:00:10.025Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 251.87,
#   'market_cap': 2417132521,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 5288859656,
#   'total_volume': 306969951,
#   'high_24h': 262.61,
#   'low_24h': 247.02,
#   'price_change_24h': -10.736090622803204,
#   'price_change_percentage_24h': -4.08827,
#   'market_cap_change_24h': -103237818.23636103,
#   'market_cap_change_percentage_24h': -4.09614,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -66.68603,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 718.64581,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.079Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 4784.89,
#   'market_cap': 2394063058,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 2426889438,
#   'total_volume': 264219062,
#   'high_24h': 4783.27,
#   'low_24h': 4688.85,
#   'price_change_24h': 72.49,
#   'price_change_percentage_24h': 1.53825,
#   'market_cap_change_24h': 1250329,
#   'market_cap_change_percentage_24h': 0.05225,
#   'circulating_supply': 500775.375,
#   'total_supply': 507641.795,
#   'max_supply': None,
#   'ath': 5619.09,
#   'ath_change_percentage': -14.93387,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 241.51193,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:52.045Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 0.677758,
#   'market_cap': 2227055456,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 4225442280,
#   'total_volume': 43496566,
#   'high_24h': 0.687403,
#   'low_24h': 0.665296,
#   'price_change_24h': 0.00878082,
#   'price_change_percentage_24h': 1.31257,
#   'market_cap_change_24h': 37504764,
#   'market_cap_change_percentage_24h': 1.7129,
#   'circulating_supply': 3277944055.53684,
#   'total_supply': 6219316794.889999,
#   'max_supply': 6219316794.89,
#   'ath': 2.86,
#   'ath_change_percentage': -76.20479,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 120.58965,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.371Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 0.999935,
#   'market_cap': 2159359299,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 2159359299,
#   'total_volume': 54689465,
#   'high_24h': 1.0,
#   'low_24h': 0.999607,
#   'price_change_24h': 9.33e-06,
#   'price_change_percentage_24h': 0.00093,
#   'market_cap_change_24h': 27191801,
#   'market_cap_change_percentage_24h': 1.27531,
#   'circulating_supply': 2159590280.873681,
#   'total_supply': 2159590280.873681,
#   'max_supply': None,
#   'ath': 1.65,
#   'ath_change_percentage': -39.56331,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 0.907561,
#   'atl_change_percentage': 10.1782,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:57.087Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 3.2,
#   'market_cap': 2029455328,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 2873225660,
#   'total_volume': 204804771,
#   'high_24h': 3.25,
#   'low_24h': 3.06,
#   'price_change_24h': 0.130007,
#   'price_change_percentage_24h': 4.23334,
#   'market_cap_change_24h': 81001520,
#   'market_cap_change_percentage_24h': 4.15722,
#   'circulating_supply': 633561603.6037512,
#   'total_supply': 896972420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -92.87248,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 210.77781,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:04.717Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 1.18,
#   'market_cap': 1981983487,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 1981983487,
#   'total_volume': 286743788,
#   'high_24h': 1.24,
#   'low_24h': 1.16,
#   'price_change_24h': 0.00421288,
#   'price_change_percentage_24h': 0.35883,
#   'market_cap_change_24h': 10511004,
#   'market_cap_change_percentage_24h': 0.53316,
#   'circulating_supply': 1679169972.026348,
#   'total_supply': 1679169972.026348,
#   'max_supply': 2100000000.0,
#   'ath': 54.98,
#   'ath_change_percentage': -97.84843,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 1.15,
#   'atl_change_percentage': 2.83508,
#   'atl_date': '2026-02-06T00:25:45.413Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:47.218Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 87.45,
#   'market_cap': 1832932711,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 1832932711,
#   'total_volume': 19313016,
#   'high_24h': 87.28,
#   'low_24h': 82.96,
#   'price_change_24h': 4.37,
#   'price_change_percentage_24h': 5.26461,
#   'market_cap_change_24h': 88242404,
#   'market_cap_change_percentage_24h': 5.05777,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 228.74,
#   'ath_change_percentage': -61.84277,
#   'ath_date': '2025-10-05T00:00:00.000Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 14932.62594,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.973Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 1.39,
#   'market_cap': 1804838517,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 1804838526,
#   'total_volume': 233113407,
#   'high_24h': 1.44,
#   'low_24h': 1.37,
#   'price_change_24h': -0.000384147424796755,
#   'price_change_percentage_24h': -0.02754,
#   'market_cap_change_24h': -1318018.3584308624,
#   'market_cap_change_percentage_24h': -0.07297,
#   'circulating_supply': 1292839018.0,
#   'total_supply': 1292839024.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -93.16243,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 165.29447,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:04.413Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 0.998707,
#   'market_cap': 1787425624,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 1787425624,
#   'total_volume': 668284,
#   'high_24h': 0.998904,
#   'low_24h': 0.997674,
#   'price_change_24h': 0.00052858,
#   'price_change_percentage_24h': 0.05295,
#   'market_cap_change_24h': 718498,
#   'market_cap_change_percentage_24h': 0.04021,
#   'circulating_supply': 1789549457.493094,
#   'total_supply': 1789549457.493094,
#   'max_supply': None,
#   'ath': 1.075,
#   'ath_change_percentage': -7.10874,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 0.943422,
#   'atl_change_percentage': 5.80553,
#   'atl_date': '2025-07-08T10:16:34.749Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:50.073Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 0.075464,
#   'market_cap': 1750923986,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 1774023967,
#   'total_volume': 11709045,
#   'high_24h': 0.076138,
#   'low_24h': 0.072909,
#   'price_change_24h': 0.00255581,
#   'price_change_percentage_24h': 3.5055,
#   'market_cap_change_24h': 61531958,
#   'market_cap_change_percentage_24h': 3.64225,
#   'circulating_supply': 23157152301.77788,
#   'total_supply': 23462665147.36596,
#   'max_supply': 23462665147.3,
#   'ath': 0.100535,
#   'ath_change_percentage': -24.82899,
#   'ath_date': '2024-12-04T10:13:57.264Z',
#   'atl': 0.03582727,
#   'atl_change_percentage': 110.93807,
#   'atl_date': '2025-02-03T05:01:48.626Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:00.020Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 0.687166,
#   'market_cap': 1690136797,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 5377597386,
#   'total_volume': 169124407,
#   'high_24h': 0.695203,
#   'low_24h': 0.659195,
#   'price_change_24h': 0.02678363,
#   'price_change_percentage_24h': 4.05578,
#   'market_cap_change_24h': 66243784,
#   'market_cap_change_percentage_24h': 4.07932,
#   'circulating_supply': 2458559719.12999,
#   'total_supply': 7822529124.595041,
#   'max_supply': 8000000000.0,
#   'ath': 2.41,
#   'ath_change_percentage': -71.47194,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 0.099713,
#   'atl_change_percentage': 589.1402,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:53.887Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 0.165631,
#   'market_cap': 1679868027,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 2584412349,
#   'total_volume': 13550678,
#   'high_24h': 0.167071,
#   'low_24h': 0.164071,
#   'price_change_24h': 0.00085838,
#   'price_change_percentage_24h': 0.52095,
#   'market_cap_change_24h': 8054852,
#   'market_cap_change_percentage_24h': 0.4818,
#   'circulating_supply': 10142200266.49829,
#   'total_supply': 15603385025.38199,
#   'max_supply': 100000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -94.45121,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 0.131244,
#   'atl_change_percentage': 26.31177,
#   'atl_date': '2026-02-11T17:06:46.605Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:02.825Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 1.78e-06,
#   'market_cap': 1627211357,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 1627211357,
#   'total_volume': 16530932,
#   'high_24h': 1.78e-06,
#   'low_24h': 1.77e-06,
#   'price_change_24h': -3.459619754e-09,
#   'price_change_percentage_24h': -0.19446,
#   'market_cap_change_24h': -3427711.0128581524,
#   'market_cap_change_percentage_24h': -0.21021,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'max_supply': 999990000000000.0,
#   'ath': 3.75e-06,
#   'ath_change_percentage': -52.67493,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 8.00816e-07,
#   'atl_change_percentage': 121.69865,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.759Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 3.77e-06,
#   'market_cap': 1584499378,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 1584499378,
#   'total_volume': 497523277,
#   'high_24h': 3.77e-06,
#   'low_24h': 3.5e-06,
#   'price_change_24h': 2.34153e-07,
#   'price_change_percentage_24h': 6.6252,
#   'market_cap_change_24h': 95903006,
#   'market_cap_change_percentage_24h': 6.44251,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -86.55488,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 6733.98823,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:57.984Z'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'image': 'https://coin-images.coingecko.com/coins/images/25380/large/UUSD.jpg?1696524513',
#   'current_price': 1.001,
#   'market_cap': 1546212301,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 1546744925,
#   'total_volume': 2916348,
#   'high_24h': 1.002,
#   'low_24h': 0.999497,
#   'price_change_24h': 0.00107964,
#   'price_change_percentage_24h': 0.10795,
#   'market_cap_change_24h': 60264472,
#   'market_cap_change_percentage_24h': 4.05563,
#   'circulating_supply': 1544405610.0,
#   'total_supply': 1544937612.0,
#   'max_supply': None,
#   'ath': 1.052,
#   'ath_change_percentage': -4.75353,
#   'ath_date': '2023-10-23T22:45:25.398Z',
#   'atl': 0.928067,
#   'atl_change_percentage': 7.94702,
#   'atl_date': '2022-06-19T16:15:11.558Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:04:03.148Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 100.85,
#   'market_cap': 1531612082,
#   'market_cap_rank': 55,
#   'fully_diluted_valuation': 1615966915,
#   'total_volume': 332603315,
#   'high_24h': 103.82,
#   'low_24h': 94.04,
#   'price_change_24h': 6.18,
#   'price_change_percentage_24h': 6.52672,
#   'market_cap_change_24h': 93336446,
#   'market_cap_change_percentage_24h': 6.48947,
#   'circulating_supply': 15164786.532628013,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -84.71689,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 288.60324,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:47.662Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 1.0,
#   'market_cap': 1446784780,
#   'market_cap_rank': 56,
#   'fully_diluted_valuation': 1446784780,
#   'total_volume': 157048877,
#   'high_24h': 1.0,
#   'low_24h': 0.999411,
#   'price_change_24h': 7.941e-05,
#   'price_change_percentage_24h': 0.00794,
#   'market_cap_change_24h': 26572952,
#   'market_cap_change_percentage_24h': 1.87106,
#   'circulating_supply': 1446761049.407244,
#   'total_supply': 1446761049.407244,
#   'max_supply': None,
#   'ath': 1.073,
#   'ath_change_percentage': -6.79777,
#   'ath_date': '2024-12-26T10:45:52.337Z',
#   'atl': 0.962292,
#   'atl_change_percentage': 3.90718,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:54.116Z'},
#  {'id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/70445/large/JTRSY.png?1762078582',
#   'current_price': 1.1,
#   'market_cap': 1422339826,
#   'market_cap_rank': 57,
#   'fully_diluted_valuation': 1422339826,
#   'total_volume': 0.0,
#   'high_24h': 1.1,
#   'low_24h': 1.1,
#   'price_change_24h': 7.7e-05,
#   'price_change_percentage_24h': 0.007,
#   'market_cap_change_24h': 50096004,
# ...
#   'market_cap_rank': 82,
#   'fully_diluted_valuation': 1231668695,
#   'total_volume': 16700.72,
#   'high_24h': 0.01238787,
#   'low_24h': 0.01143716,
#   'price_change_24h': 0.00078403,
#   'price_change_percentage_24h': 6.79802,
#   'market_cap_change_24h': 44960959,
#   'market_cap_change_percentage_24h': 6.86342,
#   'circulating_supply': 56836852995.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.060147,
#   'ath_change_percentage': -79.52234,
#   'ath_date': '2025-09-14T16:52:41.627Z',
#   'atl': 0.00940996,
#   'atl_change_percentage': 30.88986,
#   'atl_date': '2026-03-30T23:46:20.691Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:55.847Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://coin-images.coingecko.com/coins/images/26455/large/Aptos-Network-Symbol-Black-RGB-1x.png?1761789140',
#   'current_price': 0.866461,
#   'market_cap': 698569354,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 1040824831,
#   'total_volume': 86446611,
#   'high_24h': 0.874768,
#   'low_24h': 0.836603,
#   'price_change_24h': 0.02369421,
#   'price_change_percentage_24h': 2.81148,
#   'market_cap_change_24h': 19051114,
#   'market_cap_change_percentage_24h': 2.80362,
#   'circulating_supply': 806202958.1459715,
#   'total_supply': 1201192198.737075,
#   'max_supply': 2100000000.0,
#   'ath': 19.92,
#   'ath_change_percentage': -95.64997,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 0.795451,
#   'atl_change_percentage': 8.93888,
#   'atl_date': '2026-02-23T01:30:53.133Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.151Z'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'image': 'https://coin-images.coingecko.com/coins/images/11095/large/JUST.jpg?1696511035',
#   'current_price': 0.077451,
#   'market_cap': 682325553,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 682325553,
#   'total_volume': 42545542,
#   'high_24h': 0.080717,
#   'low_24h': 0.074987,
#   'price_change_24h': 0.00062482,
#   'price_change_percentage_24h': 0.81329,
#   'market_cap_change_24h': 6475134,
#   'market_cap_change_percentage_24h': 0.95807,
#   'circulating_supply': 8815108090.312735,
#   'total_supply': 8815108090.312735,
#   'max_supply': 9900000000.0,
#   'ath': 0.193254,
#   'ath_change_percentage': -59.98772,
#   'ath_date': '2021-04-05T04:34:23.454Z',
#   'atl': 0.00476275,
#   'atl_change_percentage': 1523.54589,
#   'atl_date': '2020-05-09T06:08:54.872Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:58.601Z'},
#  {'id': 'ousg',
#   'symbol': 'ousg',
#   'name': 'OUSG',
#   'image': 'https://coin-images.coingecko.com/coins/images/29023/large/OUSG.png?1696527993',
#   'current_price': 114.91,
#   'market_cap': 674919096,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 674919096,
#   'total_volume': 0.0,
#   'high_24h': 114.91,
#   'low_24h': 114.87,
#   'price_change_24h': 0.035831,
#   'price_change_percentage_24h': 0.03119,
#   'market_cap_change_24h': -1716916.58009243,
#   'market_cap_change_percentage_24h': -0.25374,
#   'circulating_supply': 5873429.701314191,
#   'total_supply': 5873429.701314191,
#   'max_supply': None,
#   'ath': 114.91,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2026-04-13T21:15:07.634Z',
#   'atl': 95.09,
#   'atl_change_percentage': 20.84325,
#   'atl_date': '2023-03-22T20:00:17.106Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:00:07.993Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'image': 'https://coin-images.coingecko.com/coins/images/16547/large/arb.jpg?1721358242',
#   'current_price': 0.111233,
#   'market_cap': 672419703,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 1113125771,
#   'total_volume': 78641559,
#   'high_24h': 0.113613,
#   'low_24h': 0.110394,
#   'price_change_24h': 0.00040483,
#   'price_change_percentage_24h': 0.36528,
#   'market_cap_change_24h': 2440030,
#   'market_cap_change_percentage_24h': 0.36419,
#   'circulating_supply': 6040824145.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.39,
#   'ath_change_percentage': -95.34187,
#   'ath_date': '2024-01-12T12:29:59.231Z',
#   'atl': 0.087087,
#   'atl_change_percentage': 27.85184,
#   'atl_date': '2026-03-29T22:50:51.753Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:57.400Z'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'image': 'https://coin-images.coingecko.com/coins/images/53746/large/trump.png?1737171561',
#   'current_price': 2.85,
#   'market_cap': 664002270,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 2855938389,
#   'total_volume': 113527988,
#   'high_24h': 2.88,
#   'low_24h': 2.81,
#   'price_change_24h': 0.01263806,
#   'price_change_percentage_24h': 0.44487,
#   'market_cap_change_24h': 3652730,
#   'market_cap_change_percentage_24h': 0.55315,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 73.43,
#   'ath_change_percentage': -96.11047,
#   'ath_date': '2025-01-19T11:50:34.806Z',
#   'atl': 2.73,
#   'atl_change_percentage': 4.61397,
#   'atl_date': '2026-03-12T14:42:04.966Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:56.306Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/2912/large/xdc-icon.png?1696503661',
#   'current_price': 0.03137116,
#   'market_cap': 625557723,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 1193916919,
#   'total_volume': 27771454,
#   'high_24h': 0.03168681,
#   'low_24h': 0.03023433,
#   'price_change_24h': 0.00032084,
#   'price_change_percentage_24h': 1.03329,
#   'market_cap_change_24h': 3432755,
#   'market_cap_change_percentage_24h': 0.55178,
#   'circulating_supply': 19942478754.87,
#   'total_supply': 38061496036.35,
#   'max_supply': None,
#   'ath': 0.192754,
#   'ath_change_percentage': -83.71846,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.00039532,
#   'atl_change_percentage': 7838.75694,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'roi': {'times': 0.7471188876258643,
#    'currency': 'eth',
#    'percentage': 74.71188876258644},
#   'last_updated': '2026-04-14T14:03:56.955Z'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'image': 'https://coin-images.coingecko.com/coins/images/5111/large/Beldex.png?1696505631',
#   'current_price': 0.080236,
#   'market_cap': 621040348,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 797589196,
#   'total_volume': 12632060,
#   'high_24h': 0.080604,
#   'low_24h': 0.080094,
#   'price_change_24h': -0.000116351885402668,
#   'price_change_percentage_24h': -0.1448,
#   'market_cap_change_24h': -504914.4308294058,
#   'market_cap_change_percentage_24h': -0.08124,
#   'circulating_supply': 7737533348.196484,
#   'total_supply': 9937153074.141684,
#   'max_supply': None,
#   'ath': 0.450785,
#   'ath_change_percentage': -82.18781,
#   'ath_date': '2018-12-17T00:00:00.000Z',
#   'atl': 0.00027519,
#   'atl_change_percentage': 29078.37671,
#   'atl_date': '2019-11-01T11:05:12.090Z',
#   'roi': {'times': -0.6790552631194239,
#    'currency': 'usd',
#    'percentage': -67.90552631194238},
#   'last_updated': '2026-04-14T14:03:58.235Z'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'image': 'https://coin-images.coingecko.com/coins/images/34188/large/jup.png?1704266489',
#   'current_price': 0.171953,
#   'market_cap': 611049957,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1181196881,
#   'total_volume': 23262276,
#   'high_24h': 0.172058,
#   'low_24h': 0.162768,
#   'price_change_24h': 0.00616528,
#   'price_change_percentage_24h': 3.71877,
#   'market_cap_change_24h': 22338009,
#   'market_cap_change_percentage_24h': 3.79439,
#   'circulating_supply': 3550835739.32,
#   'total_supply': 6863982317.530708,
#   'max_supply': 10000000000.0,
#   'ath': 2.0,
#   'ath_change_percentage': -91.39574,
#   'ath_date': '2024-01-31T15:02:47.304Z',
#   'atl': 0.135801,
#   'atl_change_percentage': 26.7195,
#   'atl_date': '2026-02-12T18:35:44.925Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.727Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://coin-images.coingecko.com/coins/images/1167/large/VET.png?1742383283',
#   'current_price': 0.00701738,
#   'market_cap': 603542594,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 603542594,
#   'total_volume': 17218614,
#   'high_24h': 0.00709747,
#   'low_24h': 0.0067811,
#   'price_change_24h': 0.00018974,
#   'price_change_percentage_24h': 2.77899,
#   'market_cap_change_24h': 16435563,
#   'market_cap_change_percentage_24h': 2.79942,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'max_supply': 86712634466.0,
#   'ath': 0.280991,
#   'ath_change_percentage': -97.50498,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 265.69141,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 0.02861530488103065,
#    'currency': 'eth',
#    'percentage': 2.861530488103065},
#   'last_updated': '2026-04-14T14:03:52.138Z'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'image': 'https://coin-images.coingecko.com/coins/images/71015/large/midnight.png?1765193080',
#   'current_price': 0.03607472,
#   'market_cap': 598737296,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 865258597,
#   'total_volume': 40894245,
#   'high_24h': 0.03945195,
#   'low_24h': 0.03526155,
#   'price_change_24h': -0.00267584959194607,
#   'price_change_percentage_24h': -6.90532,
#   'market_cap_change_24h': -45414275.12331629,
#   'market_cap_change_percentage_24h': -7.05025,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'max_supply': 24000000000.0,
#   'ath': 0.118529,
#   'ath_change_percentage': -69.57723,
#   'ath_date': '2025-12-09T09:29:38.386Z',
#   'atl': 0.02378032,
#   'atl_change_percentage': 51.63716,
#   'atl_date': '2025-12-09T09:48:36.670Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.744Z'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'image': 'https://coin-images.coingecko.com/coins/images/30663/large/gho-token-logo.png?1720517092',
#   'current_price': 0.999628,
#   'market_cap': 583769986,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 583769986,
#   'total_volume': 9201636,
#   'high_24h': 1.0,
#   'low_24h': 0.999348,
#   'price_change_24h': -4.6256197048677e-05,
#   'price_change_percentage_24h': -0.00463,
#   'market_cap_change_24h': -88447.72266638279,
#   'market_cap_change_percentage_24h': -0.01515,
#   'circulating_supply': 584000000.0,
#   'total_supply': 584000000.0,
#   'max_supply': None,
#   'ath': 1.03,
#   'ath_change_percentage': -2.93291,
#   'ath_date': '2024-02-28T17:15:58.387Z',
#   'atl': 0.917065,
#   'atl_change_percentage': 9.004,
#   'atl_date': '2023-10-24T04:41:04.568Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.269Z'},
#  {'id': 'stable-2',
#   'symbol': 'stable',
#   'name': '\u200b\u200bStable',
#   'image': 'https://coin-images.coingecko.com/coins/images/69242/large/stable-logotype-framed-square-light.png?1762753913',
#   'current_price': 0.02674215,
#   'market_cap': 583454097,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 2678833707,
#   'total_volume': 43032944,
#   'high_24h': 0.03075438,
#   'low_24h': 0.02531759,
#   'price_change_24h': -0.003250802952789376,
#   'price_change_percentage_24h': -10.83856,
#   'market_cap_change_24h': -66535348.22032106,
#   'market_cap_change_percentage_24h': -10.23637,
#   'circulating_supply': 21780153635.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.0388874,
#   'ath_change_percentage': -31.15173,
#   'ath_date': '2026-02-27T01:55:43.571Z',
#   'atl': 0.0092214,
#   'atl_change_percentage': 190.33883,
#   'atl_date': '2025-12-24T05:49:32.232Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:51.301Z'},
#  {'id': 'ylds',
#   'symbol': 'ylds',
#   'name': 'YLDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/66486/large/YLDS.png?1772560579',
#   'current_price': 0.999845,
#   'market_cap': 578177114,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 578177114,
#   'total_volume': 2223879,
#   'high_24h': 0.999892,
#   'low_24h': 0.999707,
#   'price_change_24h': -4.2864675111387e-05,
#   'price_change_percentage_24h': -0.00429,
#   'market_cap_change_24h': -22954023.76967156,
#   'market_cap_change_percentage_24h': -3.81847,
#   'circulating_supply': 578312365.69,
#   'total_supply': 578312365.69,
#   'max_supply': None,
#   'ath': 1.001,
#   'ath_change_percentage': -0.12387,
#   'ath_date': '2026-02-13T15:00:58.249Z',
#   'atl': 0.999202,
#   'atl_change_percentage': 0.06436,
#   'atl_date': '2025-11-16T12:26:29.488Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:50.498Z'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/38272/large/USD0LOGO.png?1716962811',
#   'current_price': 0.998281,
#   'market_cap': 557827227,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 557827227,
#   'total_volume': 522813,
#   'high_24h': 0.998939,
#   'low_24h': 0.992426,
#   'price_change_24h': 0.00239804,
#   'price_change_percentage_24h': 0.24079,
#   'market_cap_change_24h': 145208,
#   'market_cap_change_percentage_24h': 0.02604,
#   'circulating_supply': 558872062.3081313,
#   'total_supply': 558872062.3081313,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -24.70507,
#   'ath_date': '2024-07-12T08:28:59.311Z',
#   'atl': 0.962885,
#   'atl_change_percentage': 3.66603,
#   'atl_date': '2025-04-10T08:30:51.088Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:49.012Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12632/large/pancakeswap-cake-logo_%281%29.png?1696512440',
#   'current_price': 1.64,
#   'market_cap': 538184309,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 558689340,
#   'total_volume': 79120957,
#   'high_24h': 1.64,
#   'low_24h': 1.5,
#   'price_change_24h': 0.138143,
#   'price_change_percentage_24h': 9.20181,
#   'market_cap_change_24h': 44991470,
#   'market_cap_change_percentage_24h': 9.12249,
#   'circulating_supply': 328215496.4437591,
#   'total_supply': 340720634.4717841,
#   'max_supply': 400000000.0,
#   'ath': 43.96,
#   'ath_change_percentage': -96.27516,
#   'ath_date': '2021-04-30T10:08:22.934Z',
#   'atl': 0.194441,
#   'atl_change_percentage': 742.21713,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:47.134Z'},
#  {'id': 'siren-2',
#   'symbol': 'siren',
#   'name': 'Siren',
#   'image': 'https://coin-images.coingecko.com/coins/images/54479/large/siren.png?1739960056',
#   'current_price': 0.732757,
#   'market_cap': 533200718,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 533200718,
#   'total_volume': 17743195,
#   'high_24h': 0.812821,
#   'low_24h': 0.726726,
#   'price_change_24h': -0.05148864909569617,
#   'price_change_percentage_24h': -6.56537,
#   'market_cap_change_24h': -39712128.160741866,
#   'market_cap_change_percentage_24h': -6.93162,
#   'circulating_supply': 727274305.0434376,
#   'total_supply': 727274305.0434376,
#   'max_supply': 1000000000.0,
#   'ath': 3.61,
#   'ath_change_percentage': -79.66445,
#   'ath_date': '2026-03-22T17:26:33.134Z',
#   'atl': 0.02634736,
#   'atl_change_percentage': 2682.50523,
#   'atl_date': '2025-03-11T06:21:52.561Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:50.106Z'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'image': 'https://coin-images.coingecko.com/coins/images/28600/large/bonk.jpg?1696527587',
#   'current_price': 6.04e-06,
#   'market_cap': 531274457,
#   'market_cap_rank': 101,
#   'fully_diluted_valuation': 531274457,
#   'total_volume': 75683196,
#   'high_24h': 6.14e-06,
#   'low_24h': 5.67e-06,
#   'price_change_24h': 3.29448e-07,
#   'price_change_percentage_24h': 5.77032,
#   'market_cap_change_24h': 28979787,
#   'market_cap_change_percentage_24h': 5.76948,
#   'circulating_supply': 87994740199998.56,
#   'total_supply': 87994740199998.7,
#   'max_supply': 87995282867000.55,
#   'ath': 5.825e-05,
#   'ath_change_percentage': -89.64521,
#   'ath_date': '2024-11-20T04:01:06.465Z',
#   'atl': 8.6142e-08,
#   'atl_change_percentage': 6901.98594,
#   'atl_date': '2022-12-29T22:48:46.755Z',
#   'roi': None,
#   'last_updated': '2026-04-14T14:03:48.252Z'}]

# %%
# get_market_chart() 응답 내용(JSON) 확인
market_caps
# Out:
# [[1744675200000, 60199908506.245766],
#  [1744761600000, 60417188776.17674],
#  [1744848000000, 60482834985.68738],
#  [1744934400000, 60905068137.7922],
#  [1745020800000, 60899531624.784546],
#  [1745107200000, 60905279546.47661],
#  [1745193600000, 60912555306.20599],
#  [1745280000000, 60928832833.85901],
#  [1745366400000, 61589269101.35528],
#  [1745452800000, 61896921299.12466],
#  [1745539200000, 62129850660.586266],
#  [1745625600000, 62325968054.99818],
#  [1745712000000, 62251662906.80433],
#  [1745798400000, 62076749988.76833],
#  [1745884800000, 62026261648.921],
#  [1745971200000, 62142665088.87474],
#  [1746057600000, 61508869555.16433],
#  [1746144000000, 61469063386.18792],
#  [1746230400000, 61520122153.8279],
#  [1746316800000, 61504588129.61178],
#  [1746403200000, 61502292587.1267],
#  [1746489600000, 61786628299.92093],
#  [1746576000000, 60949351180.20576],
#  [1746662400000, 60947364928.44116],
#  [1746748800000, 60867341067.19171],
#  [1746835200000, 60689997043.40309],
#  [1746921600000, 60800003218.424],
#  [1747008000000, 60801300532.30528],
#  [1747094400000, 60886438189.638725],
#  [1747180800000, 60861380673.33633],
#  [1747267200000, 60631968614.49602],
#  [1747353600000, 60575195332.76094],
#  [1747440000000, 60805371271.162575],
#  [1747526400000, 60894170790.318344],
#  [1747612800000, 60855229769.997635],
#  [1747699200000, 60617499885.70176],
#  [1747785600000, 60660002910.37936],
#  [1747872000000, 61178036077.039345],
#  [1747958400000, 61212203672.456055],
#  [1748044800000, 61723721871.26919],
#  [1748131200000, 61721143708.71242],
#  [1748217600000, 61701492712.77306],
#  [1748304000000, 61543750452.91037],
#  [1748390400000, 61392676922.02948],
#  [1748476800000, 61255011415.83986],
#  [1748563200000, 61116764897.10546],
#  [1748649600000, 61040432498.467636],
#  [1748736000000, 60965783559.03569],
#  [1748822400000, 60910872304.54951],
#  [1748908800000, 60931561094.54832],
#  [1748995200000, 61456111625.28465],
#  [1749081600000, 61503892540.73508],
#  [1749168000000, 61192830801.60007],
#  [1749254400000, 61108371805.51531],
#  [1749340800000, 61079859748.93986],
#  [1749427200000, 61069252946.978134],
#  [1749513600000, 61025956000.80089],
#  [1749600000000, 60981759148.884056],
#  [1749686400000, 61234323266.67027],
#  [1749772800000, 61083044087.78417],
#  [1749859200000, 61668532113.59335],
#  [1749945600000, 61655886363.366],
#  [1750032000000, 61627304085.52391],
#  [1750118400000, 61627132410.14026],
#  [1750204800000, 61546152285.123375],
#  [1750291200000, 61509240699.84915],
#  [1750377600000, 61352899060.46884],
#  [1750464000000, 61254399466.51995],
#  [1750550400000, 61240656839.42593],
#  [1750636800000, 61250974946.83776],
#  [1750723200000, 61585219083.56823],
#  [1750809600000, 61904408505.33331],
#  [1750896000000, 61782873643.89733],
#  [1750982400000, 61706915980.07253],
#  [1751068800000, 61720216218.723915],
#  [1751155200000, 61708746298.92839],
#  [1751241600000, 61672471232.72115],
#  [1751328000000, 61486603678.35881],
#  [1751414400000, 61645964432.484375],
#  [1751500800000, 61785325736.27592],
#  [1751587200000, 62127723751.58684],
#  [1751673600000, 62138849073.54913],
#  [1751760000000, 62207910534.00092],
#  [1751846400000, 62222414420.9865],
#  [1751932800000, 61990294822.25617],
#  [1752019200000, 61957203749.10844],
#  [1752105600000, 62375182383.813385],
#  [1752192000000, 62830227713.91529],
#  [1752278400000, 63513728765.47138],
#  [1752364800000, 63624539540.2064],
#  [1752451200000, 63645701670.76146],
#  [1752537600000, 63390464631.81877],
#  [1752624000000, 62402203816.18168],
#  [1752710400000, 63483508990.46475],
#  [1752796800000, 64720387308.81224],
#  [1752883200000, 64791644135.09668],
#  [1752969600000, 64595341290.34144],
#  [1753056000000, 64467724533.03223],
#  [1753142400000, 64758592638.76931],
#  [1753228800000, 64754306762.01228],
#  [1753315200000, 64663762024.72109],
#  [1753401600000, 65119884120.81992],
#  [1753488000000, 64024850565.97002],
#  [1753574400000, 64270649511.54688],
#  [1753660800000, 64285647872.1984],
#  [1753747200000, 63880072658.345825],
#  [1753833600000, 63804337172.67573],
#  [1753920000000, 64003380358.56574],
#  [1754006400000, 64024628286.23601],
#  [1754092800000, 64250322579.40557],
#  [1754179200000, 64188824575.57581],
#  [1754265600000, 64165551880.33778],
#  [1754352000000, 64362866856.16951],
#  [1754438400000, 64571350833.30457],
#  [1754524800000, 64649513857.36945],
#  [1754611200000, 64762663626.17614],
#  [1754697600000, 65267428113.77714],
#  [1754784000000, 65279194197.36424],
#  [1754870400000, 65200159668.74354],
#  [1754956800000, 65582516791.05663],
#  [1755043200000, 65600277949.560524],
#  [1755129600000, 66411009283.75756],
#  [1755216000000, 67666316828.349495],
#  [1755302400000, 68162345082.25059],
#  [1755388800000, 68175449428.10462],
#  [1755475200000, 68158258982.026955],
#  [1755561600000, 68278690130.78527],
#  [1755648000000, 67919335078.96813],
#  [1755734400000, 67501312728.84719],
#  [1755820800000, 67141855554.203],
#  [1755907200000, 67542011449.1576],
#  [1755993600000, 67542228476.65118],
#  [1756080000000, 67454609360.232],
#  [1756166400000, 68044691544.51479],
#  [1756252800000, 69011841841.88863],
#  [1756339200000, 69340394517.07306],
#  [1756425600000, 70620028285.78723],
#  [1756512000000, 71541280531.89722],
#  [1756598400000, 71538548184.44302],
#  [1756684800000, 71549491496.40121],
#  [1756771200000, 71513530485.20557],
#  [1756857600000, 72146971879.89037],
#  [1756944000000, 72672911069.14882],
#  [1757030400000, 72570847322.3635],
#  [1757116800000, 72464557041.88847],
#  [1757203200000, 72547699909.17642],
#  [1757289600000, 72499319914.56313],
#  [1757376000000, 72425624280.22612],
#  [1757462400000, 72661309825.54846],
#  [1757548800000, 72353022867.15466],
#  [1757635200000, 72437004729.26895],
#  [1757721600000, 72975110549.91373],
#  [1757808000000, 73169475841.81604],
#  [1757894400000, 73194785399.01404],
#  [1757980800000, 73194539085.54532],
#  [1758067200000, 73610319439.59213],
#  [1758153600000, 73594450402.46196],
#  [1758240000000, 74338680585.20328],
#  [1758326400000, 74163618655.86676],
#  [1758412800000, 73976208429.79012],
#  [1758499200000, 73960703749.01588],
#  [1758585600000, 74131793688.85382],
#  [1758672000000, 73979784471.65208],
#  [1758758400000, 74153783390.91512],
#  [1758844800000, 73967925897.96547],
#  [1758931200000, 73769508933.57736],
#  [1759017600000, 73723140848.84122],
#  [1759104000000, 73668158839.96417],
#  [1759190400000, 73503911954.7772],
#  [1759276800000, 73395860021.48103],
#  [1759363200000, 73936203902.37366],
#  [1759449600000, 74303858028.50404],
#  [1759536000000, 75402867504.72406],
#  [1759622400000, 75340591581.69048],
#  [1759708800000, 75216551271.27759],
#  [1759795200000, 75490408399.69547],
#  [1759881600000, 75582405046.00488],
#  [1759968000000, 75665318341.2458],
#  [1760054400000, 75574178484.05225],
#  [1760140800000, 75026867754.30981],
#  [1760227200000, 75382187140.60086],
#  [1760313600000, 75639712687.31621],
#  [1760400000000, 75821593638.51003],
#  [1760486400000, 76219878474.08218],
#  [1760572800000, 76066936940.32709],
#  [1760659200000, 75948741220.90154],
#  [1760745600000, 76033638109.43999],
#  [1760832000000, 75939549186.60498],
#  [1760918400000, 75939618382.20375],
#  [1761004800000, 76201196395.60898],
#  [1761091200000, 76780747878.54977],
#  [1761177600000, 76534953556.23419],
#  [1761264000000, 76493628580.56049],
#  [1761350400000, 76326620231.9463],
#  [1761436800000, 76278128433.61526],
#  [1761523200000, 76236838551.97643],
#  [1761609600000, 76159183452.11792],
#  [1761696000000, 76198885072.7698],
#  [1761782400000, 76301584814.62709],
#  [1761868800000, 75950060281.33815],
#  [1761955200000, 75912385027.86111],
#  [1762041600000, 75855338093.96507],
#  [1762128000000, 75797588536.42018],
#  [1762214400000, 75556937074.62796],
#  [1762300800000, 75145449692.42545],
#  [1762387200000, 75296518973.28085],
#  [1762473600000, 75451938946.93945],
#  [1762560000000, 75779329530.51295],
#  [1762646400000, 75700645708.50941],
#  [1762732800000, 75757366577.00575],
#  [1762819200000, 76155747955.87144],
#  [1762905600000, 75967424757.97282],
#  [1762992000000, 76052521919.11623],
#  [1763078400000, 75578542259.78708],
#  [1763164800000, 74989995354.03566],
#  [1763251200000, 74928978465.23138],
#  [1763337600000, 74854938591.16776],
#  [1763424000000, 74892956509.57384],
#  [1763510400000, 74880488294.86015],
#  [1763596800000, 74643339219.06718],
#  [1763683200000, 73909788280.45352],
#  [1763769600000, 74040826913.06186],
#  [1763856000000, 74004667844.06729],
#  [1763942400000, 74068748779.50249],
#  [1764028800000, 74501543758.89574],
#  [1764115200000, 75168587746.09627],
#  [1764201600000, 75754672529.57784],
#  [1764288000000, 76024535653.55592],
#  [1764374400000, 76529002202.7604],
#  [1764460800000, 76543535518.57362],
#  [1764547200000, 76589515806.04205],
#  [1764633600000, 77509820034.28696],
#  [1764720000000, 77509490840.23564],
#  [1764806400000, 77812656340.26474],
#  [1764892800000, 78052939534.6978],
#  [1764979200000, 78062265665.87842],
#  [1765065600000, 78125782618.12518],
#  [1765152000000, 78177215513.57675],
#  [1765238400000, 78322005232.93845],
#  [1765324800000, 78461039498.99965],
#  [1765411200000, 78247279770.47147],
#  [1765497600000, 78273133759.30103],
#  [1765584000000, 78479111692.53076],
#  [1765670400000, 78424700012.9138],
#  [1765756800000, 78400153698.20047],
#  [1765843200000, 78445964850.04926],
#  [1765929600000, 78315434993.7644],
#  [1766016000000, 78042840696.92249],
#  [1766102400000, 77331627180.34195],
#  [1766188800000, 77093596994.70663],
#  [1766275200000, 77077940358.12505],
#  [1766361600000, 77107714886.00273],
#  [1766448000000, 77107982651.43582],
#  [1766534400000, 76915464264.76744],
#  [1766620800000, 76591043824.28026],
#  [1766707200000, 76476959213.82686],
#  [1766793600000, 76517544120.7733],
#  [1766880000000, 76474911697.4624],
#  [1766966400000, 76384734230.46066],
#  [1767052800000, 76016098863.74144],
#  [1767139200000, 76008223428.32848],
#  [1767225600000, 75371182421.47166],
#  [1767312000000, 75187332687.29697],
#  [1767398400000, 75338085489.51773],
#  [1767484800000, 75382811888.47682],
#  [1767571200000, 75441548669.84816],
#  [1767657600000, 75769878326.6978],
#  [1767744000000, 75749018875.95282],
#  [1767830400000, 75208766704.42323],
#  [1767916800000, 74977683650.8868],
#  [1768003200000, 74787856335.98029],
#  [1768089600000, 74713286205.17264],
#  [1768176000000, 74629591185.86687],
#  [1768262400000, 74341587408.56544],
#  [1768348800000, 75016056899.61877],
#  [1768435200000, 75806879075.3657],
#  [1768521600000, 75673057112.48198],
#  [1768608000000, 75985424473.90607],
#  [1768694400000, 76020188662.64745],
#  [1768780800000, 75956415747.38663],
#  [1768867200000, 75815735295.47107],
#  [1768953600000, 74927824593.92998],
#  [1769040000000, 74440160183.65816],
#  [1769126400000, 73725876877.11763],
#  [1769212800000, 72893696034.71667],
#  [1769299200000, 72525746654.4399],
#  [1769385600000, 72391867384.72154],
#  [1769472000000, 72062863058.69075],
#  [1769558400000, 71545146183.63538],
#  [1769644800000, 71222533431.20903],
#  [1769731200000, 70300438185.34792],
#  [1769817600000, 70048084221.75757],
#  [1769904000000, 70165928923.21927],
#  [1769990400000, 70278789633.51726],
#  [1770076800000, 70641107077.41772],
#  [1770163200000, 70764424031.34343],
#  [1770249600000, 70724659469.83084],
#  [1770336000000, 70621497254.34673],
#  [1770422400000, 72486291025.07703],
#  [1770508800000, 72663403646.94044],
#  [1770595200000, 72853256563.12044],
#  [1770681600000, 73017621342.34886],
#  [1770768000000, 73298558614.85742],
#  [1770854400000, 73327256816.46031],
#  [1770940800000, 73161159172.6478],
#  [1771027200000, 73476716063.94586],
#  [1771113600000, 73538747787.5806],
#  [1771200000000, 73608499482.57],
#  [1771286400000, 73679064910.16641],
#  [1771372800000, 73499968672.9741],
#  [1771459200000, 73581990881.96634],
#  [1771545600000, 73854460914.97928],
#  [1771632000000, 74439728036.96278],
#  [1771718400000, 74455440992.85896],
#  [1771804800000, 74435063995.43195],
#  [1771891200000, 74770549337.12044],
#  [1771977600000, 74927198039.54846],
#  [1772064000000, 75352262969.77148],
#  [1772150400000, 75314838727.91203],
#  [1772236800000, 75227319202.03062],
#  [1772323200000, 75184269623.3704],
#  [1772409600000, 75192261862.23296],
#  [1772496000000, 75933895612.55305],
#  [1772582400000, 76330431281.0647],
#  [1772668800000, 77066875508.36983],
#  [1772755200000, 77163682665.69066],
#  [1772841600000, 77338993283.97954],
#  [1772928000000, 77256826391.67438],
#  [1773014400000, 77239570378.56953],
#  [1773100800000, 78207613126.26581],
#  [1773187200000, 78672040314.52556],
#  [1773273600000, 78807446763.98502],
#  [1773360000000, 78810170251.4458],
#  [1773446400000, 79209014629.64243],
#  [1773532800000, 79188577197.11958],
#  [1773619200000, 79149237129.9105],
#  [1773705600000, 79300229487.66437],
#  [1773792000000, 79617224110.07278],
#  [1773878400000, 79432600574.47002],
#  [1773964800000, 79240632955.95074],
#  [1774051200000, 79060219421.05858],
#  [1774137600000, 79017544107.28935],
#  [1774224000000, 78975467285.87347],
#  [1774310400000, 78647783334.62715],
#  [1774396800000, 78637661360.63583],
#  [1774483200000, 78651029793.18867],
#  [1774569600000, 78065824234.8928],
#  [1774656000000, 77752987029.2416],
#  [1774742400000, 77749073498.5849],
#  [1774828800000, 77718040003.31131],
#  [1774915200000, 77437649563.11867],
#  [1775001600000, 77143883325.30286],
#  [1775088000000, 77146050319.86108],
#  [1775174400000, 77191483582.91728],
#  [1775260800000, 77551428138.9955],
#  [1775347200000, 77509138422.18379],
#  [1775433600000, 77492224390.92285],
#  [1775520000000, 77852436113.92717],
#  [1775606400000, 77801523706.03574],
#  [1775692800000, 78238941523.04596],
#  [1775779200000, 78355755574.5709],
#  [1775865600000, 78670006535.95605],
#  [1775952000000, 78635700243.44542],
#  [1776038400000, 78607553190.67357],
#  [1776124800000, 78751690956.77441],
#  [1776175519000, 78641190365.84499]]
